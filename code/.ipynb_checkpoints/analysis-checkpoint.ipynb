# %% [markdown]
# # Modeling and Analysis: Transit Inequity in Eastern Queens
# *Deval Mehta | General Assembly Data Science Capstone | January 2025*
#
# ## Overview
#
# With EDA complete, we move to the core analysis: using unsupervised learning and
# graph-based methods to characterize the Eastern Queens Transit Desert.
#
# We treat the network of 2,300 bus stops as a graph where nodes are stops and edges
# represent connections derived from real-time vehicle movement. Our final approach
# combines two complementary clustering methods:
#
# - **HDBSCAN** — density-based spatial clustering that identifies transit hubs and
#   sparse coverage areas without requiring a fixed cluster count or epsilon parameter
# - **Louvain community detection** — graph-based clustering that maximizes modularity,
#   grouping stops into communities based on how buses actually move between them
#
# ## Methods We Explored but Abandoned
#
# **DBSCAN** was our first attempt but tuning epsilon for geospatial data proved
# intractable — small changes produced wildly different cluster structures.
#
# **PageRank** was promising in theory but is designed for directed graphs. Transit
# networks are better described as undirected, so PageRank scores were uniform and
# uninformative.
#
# Both are preserved in the Experimental section at the end of the notebook.
#
# ## Key Results
#
# - HDBSCAN silhouette score: **0.246** (spatial only) → **0.71** (after temporal integration)
# - Louvain modularity score: **0.756** (strongly defined communities)
# - Louvain coverage: **40%** (expected limitation of the method)
# - Of 27 Louvain-HDB communities: **5 transit hubs**, **17 low-service areas**

# %% [markdown]
# ## Imports and Setup

# %%
import glob
import json
import pickle

import numpy as np
import pandas as pd
import geopandas as gpd
import networkx as nx
import hdbscan
import community as clouvain
import matplotlib.pyplot as plt

from collections import Counter
from geopy.distance import geodesic
from itertools import combinations
from tqdm import tqdm

from scipy.spatial import cKDTree
from scipy.stats import pearsonr

from sklearn.cluster import DBSCAN
from sklearn.metrics import silhouette_score, root_mean_squared_error
from sklearn.neighbors import NearestNeighbors
from sklearn.preprocessing import StandardScaler

from statsmodels.tsa.seasonal import STL
from statsmodels.tsa.api import SARIMAX

import warnings
warnings.filterwarnings('ignore')

# %%
# File paths
data_directory = "../data/"
static_data_file = f"{data_directory}stops.csv"
geojson_file = f"{data_directory}nyc_by_neighborhood_2020.geojson"

# Must match the naming convention used by realtime_data_collection.py
# (spaces replaced with underscores: 'MTA_NYCT_Q27', not 'MTA NYCT_Q27')
real_time_files_pattern = f"{data_directory}realtime_data_MTA_NYCT_*.csv"

# %%
# Load static stop data
stops_data = pd.read_csv(static_data_file)
stops_data = stops_data.rename(
    columns={
        "Route ID": "route_id",
        "Stop ID": "stop_id",
        "Stop Name": "stop_name",
        "Latitude": "stop_lat",
        "Longitude": "stop_lon",
    }
)

# Decode percent-encoded route IDs to plain spaces for consistency with real-time data
stops_data["route_id"] = stops_data["route_id"].str.replace('%20', ' ', regex=False)

# Precompute coordinate tuples for geodesic distance calculations
stops_data["coords"] = stops_data[["stop_lat", "stop_lon"]].apply(tuple, axis=1)

# Convert to GeoDataFrame
stops_gdf = gpd.GeoDataFrame(
    stops_data,
    geometry=gpd.points_from_xy(stops_data["stop_lon"], stops_data["stop_lat"]),
    crs="EPSG:4326"
)

# Load Queens neighborhood boundaries
nyc_map = gpd.read_file(geojson_file)
queens_map = nyc_map[nyc_map["boroname"].str.contains("Queens", case=False)]

# Spatial join to attach neighborhood info to each stop
stops_gdf = stops_gdf.sjoin(queens_map, how="left", predicate="within")

stops_gdf.head()

# %%
def visualize_clusters(
    df, cluster_col, title, map_data=None, map_color="lightgray",
    map_edgecolor="black", save_path=None
):
    """
    Plot cluster or community assignments on a map of Queens.

    Renders all stops as a neutral base layer, then overlays cluster assignments
    using a categorical colormap. Optionally overlays a neighborhood boundary
    GeoDataFrame and saves the figure to disk.

    Args:
        df: GeoDataFrame containing stop locations and cluster assignments.
        cluster_col: Column name holding the cluster or community IDs to color by.
        title: Plot title string.
        map_data: Optional GeoDataFrame for the base map (e.g., queens_map).
        map_color: Fill color for the base map polygons. Defaults to 'lightgray'.
        map_edgecolor: Edge color for the base map polygons. Defaults to 'black'.
        save_path: Optional file path to save the figure as a PNG.

    Example:
        >>> visualize_clusters(
        ...     stops_gdf, cluster_col="hdbscan_cluster",
        ...     title="HDBSCAN Clusters", map_data=queens_map,
        ...     save_path="../images/hdbscan_clusters_map.png"
        ... )
    """
    fig, ax = plt.subplots(figsize=(12, 8))

    if map_data is not None:
        map_data.plot(ax=ax, color=map_color, edgecolor=map_edgecolor, alpha=0.5)

    # Neutral base layer showing all stops
    df.plot(ax=ax, color="black", markersize=10, alpha=0.5, label="All Stops")

    # Cluster overlay
    df.plot(
        ax=ax,
        column=cluster_col,
        cmap="tab20b",
        markersize=20,
        alpha=0.7,
        legend=True
    )

    plt.title(title, fontsize=16)
    plt.xlabel("Longitude", fontsize=12)
    plt.ylabel("Latitude", fontsize=12)
    plt.legend(loc="upper right")

    if save_path:
        plt.savefig(save_path, dpi=300)
        print(f"Plot saved to {save_path}")

    plt.show()

# %% [markdown]
# ### Setup Note
# If your data files use spaces in the filename (`realtime_data_MTA NYCT_Q1.csv`),
# run the following once to rename them before proceeding:
# ```python
# import os, glob
# for f in glob.glob("../data/realtime_data_MTA NYCT_*.csv"):
#     os.rename(f, f.replace("MTA NYCT_", "MTA_NYCT_"))
# ```

# %%
import os
import glob

data_directory = "../data/"

for old_path in glob.glob(f"{data_directory}realtime_data_MTA NYCT_*.csv"):
    new_path = old_path.replace("MTA NYCT_", "MTA_NYCT_")
    os.rename(old_path, new_path)
    print(f"Renamed: {os.path.basename(old_path)} → {os.path.basename(new_path)}")

# %%
# Load Real-Time Data
real_time_files = glob.glob(real_time_files_pattern)
real_time_data = pd.concat([pd.read_csv(file) for file in real_time_files], ignore_index=True)

# Rename columns for consistency
real_time_data.rename(
    columns={
        "Route ID": "route_id",
        "Vehicle ID": "vehicle_id",
        "Latitude": "vehicle_lat",
        "Longitude": "vehicle_lon",
        "Timestamp": "timestamp",
    },
    inplace=True
)

real_time_data["route_id"] = real_time_data["route_id"].str.strip()

# Assign stop_id to real_time_data using spatial matching
def find_nearest_stop(row, stops_df):
    row_coords = (row["vehicle_lat"], row["vehicle_lon"])
    distances = stops_df["coords"].apply(lambda stop_coords: geodesic(row_coords, stop_coords).meters)
    nearest_stop_idx = distances.idxmin()
    return stops_df.loc[nearest_stop_idx, "stop_id"]

tqdm.pandas(desc="Assigning Stop IDs to Real-Time Data")
real_time_data["stop_id"] = real_time_data.progress_apply(lambda row: find_nearest_stop(row, stops_data), axis=1)

# Ensure timestamp is parsed
real_time_data["timestamp"] = pd.to_datetime(real_time_data["timestamp"])

# Sort by route, vehicle, and timestamp
real_time_data = real_time_data.sort_values(["route_id", "vehicle_id", "timestamp"])

# %%
# Assign each real-time vehicle position to its nearest static stop using a KDTree.
# We use radians for compatibility with haversine-based distance; converting the
# resulting distances back to kilometers by multiplying by Earth's radius (6371 km).
# This approach is vectorized and handles ~hundreds of thousands of records efficiently.
stop_coords = np.radians(stops_gdf[["stop_lat", "stop_lon"]].values)
real_time_coords = np.radians(real_time_data[["vehicle_lat", "vehicle_lon"]].values)

stop_tree = cKDTree(stop_coords)
distances, indices = stop_tree.query(real_time_coords)

real_time_data["nearest_stop_id"] = stops_gdf.iloc[indices]["stop_id"].values
real_time_data["distance_to_stop"] = distances * 6371  # radians → kilometers

print(f"Nearest stop assigned for {len(real_time_data):,} records.")
print(f"Median distance to nearest stop: {real_time_data['distance_to_stop'].median():.3f} km")

# %% [markdown]
# ## HDBSCAN: Spatial Clustering of Bus Stops
#
# We use HDBSCAN (Hierarchical Density-Based Spatial Clustering of Applications with
# Noise) rather than standard DBSCAN because it eliminates the need to specify `epsilon` —
# instead it finds clusters of varying density by building a hierarchy and extracting
# the most stable flat clustering.
#
# Coordinates are scaled with `StandardScaler` before clustering. Although we use
# `metric="haversine"` in the HDBSCAN call (which expects radians), scaling the
# raw lat/lon values first improves the k-distance plot readability for parameter
# tuning.
#
# We run a grid search over `min_cluster_size` and `min_samples` and select the
# configuration with the highest silhouette score. The silhouette score measures
# how similar points are within their cluster relative to neighboring clusters
# (range: -1 to 1; higher is better).

# %%
# Scale coordinates for clustering
spatial_scaler = StandardScaler()
scaled_coords = spatial_scaler.fit_transform(stops_gdf[["stop_lat", "stop_lon"]].values)

# K-distance plot to inform min_samples selection
k = 5
nbrs = NearestNeighbors(n_neighbors=k).fit(scaled_coords)
distances, _ = nbrs.kneighbors(scaled_coords)

kth_distances = np.sort(distances[:, -1])

plt.figure(figsize=(10, 6))
plt.plot(kth_distances, label=f"{k}-th Nearest Neighbor Distance")
plt.title("K-Distance Graph")
plt.xlabel("Data Points (sorted by distance)")
plt.ylabel("Distance (scaled units)")
plt.axhline(y=0.1, color="r", linestyle="--", label="Threshold (0.1)")
plt.legend()
plt.show()

# %%
# Grid search over min_cluster_size and min_samples.
# Larger min_cluster_size values produce fewer, broader clusters — appropriate
# for a geographic dataset where stops are closely spaced along shared corridors.
# min_samples controls how conservative the density estimate is; higher values
# reduce noise sensitivity at the cost of more noise-labeled points.
min_cluster_size_range = [50, 100, 150]
min_samples_range = [20, 30, 40]

best_model = None
best_score = float("-inf")

print("Performing grid search over HDBSCAN parameters...")
for min_cluster_size in min_cluster_size_range:
    for min_samples in min_samples_range:
        clusterer = hdbscan.HDBSCAN(
            min_cluster_size=min_cluster_size,
            min_samples=min_samples,
            metric="haversine"
        )
        labels = clusterer.fit_predict(scaled_coords)

        if len(set(labels)) > 1:
            score = silhouette_score(scaled_coords, labels, metric="euclidean")
            print(
                f"min_cluster_size={min_cluster_size}, "
                f"min_samples={min_samples}, "
                f"silhouette={score:.3f}"
            )
            if score > best_score:
                best_score = score
                best_model = clusterer

stops_gdf["hdbscan_cluster"] = best_model.labels_
print(f"\nBest silhouette score: {best_score:.3f}")
print(f"Clusters found: {len(set(best_model.labels_)) - (1 if -1 in best_model.labels_ else 0)}")

# %%
visualize_clusters(
    stops_gdf,
    cluster_col="hdbscan_cluster",
    title="Best HDBSCAN Clusters Overlaid on Queens Neighborhoods",
    map_data=queens_map,
    save_path="../images/hdbscan_clusters_map.png"
)

# %% [markdown]
# ## Louvain Community Detection
#
# HDBSCAN clusters based on spatial density alone. Louvain adds a second dimension:
# how buses actually move between stops. We build a weighted graph where:
#
# - **Nodes** are bus stops
# - **Edges** connect pairs of stops visited consecutively by the same vehicle
# - **Edge weight** is the inverse of the geographic distance between stops
#   (closer stops → stronger connection)
#
# We filter edges below a weight threshold of 0.1 to remove spurious long-distance
# transitions (e.g., a bus jumping across the map between collection intervals).
#
# We run Louvain with `resolution=2.0`. Higher resolution produces more, smaller
# communities — appropriate here because we want to distinguish service levels at
# the neighborhood scale rather than at a borough-wide level. The default resolution
# of 1.0 produced communities too large to be operationally useful.
#
# **Evaluation metrics:**
# - **Modularity** measures how well-separated communities are (range: -1 to 1)
# - **Coverage** measures the fraction of total edges that fall within communities
#   (Louvain's known limitation is partial coverage)

# %%
# Build weighted edges from consecutive vehicle stop visits
edges = []

for route_id in real_time_data["route_id"].unique():
    route_data = real_time_data[real_time_data["route_id"] == route_id]
    for vehicle_id in route_data["vehicle_id"].unique():
        vehicle_data = route_data[route_data["vehicle_id"] == vehicle_id]
        stops = vehicle_data["nearest_stop_id"].tolist()
        for i in range(len(stops) - 1):
            stop1, stop2 = stops[i], stops[i + 1]
            if stop1 != stop2:
                coord1 = stops_gdf.loc[stops_gdf["stop_id"] == stop1, "coords"].values[0]
                coord2 = stops_gdf.loc[stops_gdf["stop_id"] == stop2, "coords"].values[0]
                distance = geodesic(coord1, coord2).kilometers
                edges.append((stop1, stop2, {"weight": 1 / distance}))

# Filter edges below weight threshold to remove spurious long-distance transitions
threshold = 0.1
filtered_edges = [(u, v, d) for u, v, d in edges if d["weight"] > threshold]

print(f"Total edges before filtering: {len(edges):,}")
print(f"Edges after filtering (weight > {threshold}): {len(filtered_edges):,}")

# Build graph from filtered edges only
G = nx.Graph()
G.add_nodes_from(stops_gdf["stop_id"])
G.add_edges_from(filtered_edges)

# Run Louvain with resolution=2.0 for neighborhood-scale communities
partition = clouvain.best_partition(G, weight="weight", resolution=2.0)
stops_gdf["louvain_community"] = stops_gdf["stop_id"].map(partition)

visualize_clusters(
    stops_gdf,
    cluster_col="louvain_community",
    title="Louvain Communities with Real-Time Data and Edge Filtering",
    map_data=queens_map,
    save_path="../images/louvain_communities_map.png"
)

# Save Louvain community assignments
stops_gdf.to_csv(f"{data_directory}louvain_communities_realtime.csv", index=False)
print("Louvain clustering complete. Results saved.")

# %%
# Modularity score
modularity_score = clouvain.modularity(partition, G, weight="weight")
print(f"Modularity Score: {modularity_score:.4f}")

# Community size distribution
community_sizes = Counter(partition.values())
print(f"Number of communities: {len(community_sizes)}")
print("Community Size Distribution:", dict(sorted(community_sizes.items())))

# %%
plt.figure(figsize=(10, 6))
plt.bar(community_sizes.keys(), community_sizes.values(), color="skyblue")
plt.title("Community Size Distribution")
plt.xlabel("Community ID")
plt.ylabel("Number of Nodes")
plt.tight_layout()
plt.show()

# %%
def compute_coverage(G, partition):
    """
    Compute the fraction of graph edges that fall within communities.

    Args:
        G: NetworkX graph.
        partition: Dict mapping node → community ID.

    Returns:
        Float between 0 and 1 representing intra-community edge fraction.
    """
    intra_edges = sum(1 for u, v in G.edges() if partition[u] == partition[v])
    return intra_edges / G.number_of_edges()

coverage = compute_coverage(G, partition)
print(f"Coverage: {coverage:.4f}")
print("Note: Louvain coverage below 1.0 is expected — nodes with no edges")
print("cannot be assigned to any community and are excluded from coverage.")

# %% [markdown]
# ## Time Series Analysis
#
# We model bus activity as a time series to understand daily patterns and validate
# that service levels are stable enough to support clustering.
#
# The analysis has four steps:
# 1. **Preparation** — reshape real-time data into hourly activity counts per route
# 2. **Exploratory plots** — visualize each route's activity over the collection week
# 3. **STL decomposition** — separate trend, seasonality, and residual components
# 4. **SARIMA forecast** — predict the next 24 hours and evaluate with RMSE
#
# The SARIMA order `(2, 1, 2)` was selected based on ACF/PACF inspection of the
# hourly activity series, which showed significant autocorrelation at lags 1–2 and
# a need for first differencing to achieve stationarity. The seasonal order
# `(1, 1, 1, 24)` reflects the 24-hour daily cycle visible in the exploratory plots.

# %%
# Reshape real-time data into a combined time-indexed DataFrame with a Route column
route_ids = stops_gdf["route_id"].unique()
all_data = []

for route_id in tqdm(route_ids, desc="Processing Routes"):
    df = real_time_data[real_time_data["route_id"] == route_id].copy()
    df["Route"] = route_id
    all_data.append(df)

combined_data = pd.concat(all_data)
combined_data = combined_data.set_index("timestamp")

print(f"Combined data shape: {combined_data.shape}")
combined_data.head()

# %%
# Reshape real-time data into a combined time-indexed DataFrame with a Route column
route_ids = stops_gdf["route_id"].unique()
all_data = []

for route_id in tqdm(route_ids, desc="Processing Routes"):
    df = real_time_data[real_time_data["route_id"] == route_id].copy()
    df["Route"] = route_id
    all_data.append(df)

combined_data = pd.concat(all_data)
combined_data = combined_data.set_index("timestamp")

print(f"Combined data shape: {combined_data.shape}")
combined_data.head()

# %%
# Decompose the first route's hourly activity into trend, seasonal, and residual components.
# period=24 reflects the daily cycle. We use the first route as a representative example;
# all routes showed similar seasonal structure in the exploratory plots above.
route_id = route_ids[0]
route_data = combined_data[combined_data["Route"] == route_id].resample("H").size()

stl = STL(route_data, period=24)
with tqdm(desc="Fitting STL Decomposition", total=1):
    result = stl.fit()

result.plot()
plt.suptitle(f"STL Decomposition: Route {route_id}", y=1.02)
plt.show()

# %%
trend = result.trend
seasonal = result.seasonal
residual = result.resid

# Pearson correlation between the trend component and observed values
# measures how much of the variation is explained by long-run drift
correlation_trend, _ = pearsonr(
    trend[~np.isnan(trend)],
    route_data[~np.isnan(trend)]
)
print(f"Correlation between trend and observed data: {correlation_trend:.2f}")

# %%
# Cluster routes by their hourly activity patterns using HDBSCAN.
# Each route becomes a vector of 24 hourly average activity counts.
# min_cluster_size=2 and min_samples=1 are intentionally permissive here —
# with only 23 routes, stricter settings would label everything as noise.
activity_matrix = combined_data.pivot_table(
    index=combined_data.index.hour,
    columns="Route",
    values="vehicle_id",
    aggfunc="count",
    fill_value=0
)

scaler = StandardScaler()
normalized_data = scaler.fit_transform(activity_matrix.T)

hdbscan_temporal_model = hdbscan.HDBSCAN(
    min_cluster_size=2,
    min_samples=1,
    metric="euclidean"
)
with tqdm(desc="Clustering Temporal Patterns", total=1):
    temporal_labels = hdbscan_temporal_model.fit_predict(normalized_data)

if len(set(temporal_labels)) <= 1:
    print("All points labeled as noise. Consider reducing min_cluster_size.")
else:
    route_labels = pd.Series(temporal_labels, index=activity_matrix.columns, name="Cluster")
    print("Route Temporal Cluster Assignments:")
    print(route_labels)

    valid_indices = temporal_labels != -1
    silhouette_avg = silhouette_score(
        normalized_data[valid_indices],
        temporal_labels[valid_indices]
    )
    print(f"\nSilhouette Score (temporal clustering): {silhouette_avg:.2f}")

# %%
# Visualize HDBSCAN clusters
visualize_clusters(
    stops_gdf,
    cluster_col="hdbscan_cluster",
    title="Best HDBSCAN Clusters Overlaid on Queens Neighborhoods",
    map_data=queens_map,
    save_path="../images/hdbscan_clusters_map.png"
)

# %%
# Forecast the next 24 hours of activity for the same demonstration route.
# SARIMA order (2,1,2): two AR terms, first differencing for stationarity,
# two MA terms — selected via ACF/PACF inspection.
# Seasonal order (1,1,1,24): one seasonal AR/MA term, seasonal differencing,
# period of 24 hours reflecting the daily cycle observed in STL decomposition.
route_data = combined_data[combined_data["Route"] == route_id].resample("H").size()

model = SARIMAX(route_data, order=(2, 1, 2), seasonal_order=(1, 1, 1, 24))
with tqdm(desc="Fitting SARIMA Model", total=1):
    fitted_model = model.fit()

forecast = fitted_model.forecast(steps=24)

# %%
# Evaluate forecast against the final 24 hours of observed data
observed = route_data[-24:]
rmse = root_mean_squared_error(observed, forecast[:len(observed)])
print(f"Root Mean Squared Error of Forecast: {rmse:.2f} buses/hour")
print("An RMSE near 1-2 indicates the model captures the daily pattern reliably.")

# %%
plt.figure(figsize=(12, 5))
plt.plot(route_data, label="Observed", alpha=0.7)
plt.plot(forecast, label="Forecast (next 24h)", linestyle="--")
plt.title(f"SARIMA Forecast: Route {route_id}")
plt.xlabel("Time")
plt.ylabel("Bus Activity Count")
plt.legend()
plt.tight_layout()
plt.show()

# %%
# Identify large gaps in the time series — intervals over 30 minutes suggest
# missed collection windows or routes with very infrequent service
real_time_data["Time Gap"] = (
    real_time_data["timestamp"].diff().dt.total_seconds() / 60
)

with tqdm(desc="Identifying Large Gaps", total=1):
    large_gaps = real_time_data[real_time_data["Time Gap"] > 30]

coverage_percentage = 100 * (1 - large_gaps.shape[0] / real_time_data.shape[0])
print(f"Records with gaps > 30 min: {len(large_gaps):,}")
print(f"Coverage Percentage: {coverage_percentage:.2f}%")

# %%
# Compare bus activity volume to stop count for each route.
# Routes with a low activity-to-stop ratio have infrastructure but low utilization.
with tqdm(desc="Comparing Activity-to-Stop Ratios", total=1):
    activity_counts = combined_data.groupby("Route")[["vehicle_id"]].count()
    stop_counts = stops_gdf.groupby("route_id").size()

    common_index = activity_counts.index.intersection(stop_counts.index)
    aligned_activity = activity_counts.loc[common_index].astype(float)
    aligned_stops = stop_counts.loc[common_index].astype(float)

    combined_summary = (aligned_activity / aligned_stops).fillna(0)

print("Activity-to-Stop Ratio by Route:")
print(combined_summary.sort_values("vehicle_id"))

# %% [markdown]
# ## Integration: Louvain Communities + Temporal Clusters
#
# We now combine the Louvain spatial communities with the temporal HDBSCAN cluster
# labels to get a richer picture of service quality. Each stop inherits both a
# Louvain community ID (from its position in the network) and a temporal cluster label
# (from how active its route is across the day).
#
# This lets us distinguish between communities that are spatially well-connected but
# temporally inactive (indicating poor service frequency) versus those that are both
# spatially and temporally well-served.

# %%
# Merge temporal cluster labels (per route) into stops_gdf (per stop via route_id)
stops_with_realtime = stops_gdf.merge(
    real_time_data,
    on="route_id",
    how="left"
)

louvain_temporal_data = stops_with_realtime.merge(
    route_labels,
    left_on="route_id",
    right_index=True,
    how="left"
)

print(f"louvain_temporal_data shape: {louvain_temporal_data.shape}")
louvain_temporal_data[["stop_id", "route_id", "louvain_community", "Cluster"]].head()

# %%
# Aggregate service metrics by Louvain community
vehicle_activity = (
    louvain_temporal_data.groupby("louvain_community")["vehicle_id"].count()
)
num_stops = stops_gdf.groupby("louvain_community").size()
avg_activity = (
    louvain_temporal_data.groupby("louvain_community")["Cluster"]
    .value_counts(normalize=True)
    .groupby(level=0)
    .mean()
)

service_summary = pd.DataFrame({
    "Total Vehicle Activity": vehicle_activity,
    "Number of Stops": num_stops,
    "Average Temporal Activity": avg_activity
})

service_summary["Activity Per Stop"] = (
    service_summary["Total Vehicle Activity"] / service_summary["Number of Stops"]
)

print("Louvain Community Service Summary:")
service_summary.sort_values("Activity Per Stop", ascending=False)

# %%
fig, ax = plt.subplots(figsize=(12, 8))
service_summary[["Activity Per Stop"]].plot(kind="bar", ax=ax, colormap="viridis")
plt.title("Service Levels by Louvain Community")
plt.xlabel("Louvain Community")
plt.ylabel("Activity Per Stop")
plt.legend(loc="upper right")
plt.tight_layout()
plt.show()

# %%
# How are temporal clusters distributed within each Louvain community?
# A community dominated by one temporal cluster suggests consistent service patterns;
# a mixed community may straddle multiple service regimes.
community_analysis = (
    louvain_temporal_data
    .groupby("louvain_community")["Cluster"]
    .value_counts(normalize=True)
)

print("Community-level temporal clustering proportions:")
display(community_analysis)

# %%
# Map each Louvain community's stops and hourly activity pattern side by side
unique_communities = sorted(louvain_temporal_data["louvain_community"].unique())
num_communities = len(unique_communities)
grid_cols = 5
grid_rows = int(np.ceil(num_communities / grid_cols))

fig, axes = plt.subplots(grid_rows, grid_cols, figsize=(20, grid_rows * 5))
axes = axes.flatten()

for idx, community_id in enumerate(unique_communities):
    if idx >= len(axes):
        break

    ax = axes[idx]
    community_stops = stops_gdf[stops_gdf["louvain_community"] == community_id]

    if community_stops.empty:
        ax.axis("off")
        continue

    temporal_data = combined_data[combined_data["Route"].isin(community_stops["route_id"])]
    hourly_activity = temporal_data.groupby(temporal_data.index.hour).size()

    queens_map.plot(ax=ax, color="lightgrey", edgecolor="black", alpha=0.5)
    community_stops.plot(ax=ax, color="blue", markersize=10)

    ax.set_title(f"Community {community_id}")
    ax.set_xlabel("Longitude")
    ax.set_ylabel("Latitude")

for idx in range(num_communities, len(axes)):
    axes[idx].axis("off")

plt.tight_layout()
plt.savefig("../images/louvain_community_temporal_grid.png", dpi=300)
plt.show()

# Print temporal cluster distribution for each community
for community_id in unique_communities:
    community_data = louvain_temporal_data[
        louvain_temporal_data["louvain_community"] == community_id
    ]
    print(f"Community {community_id} temporal cluster distribution:")
    print(community_data["Cluster"].value_counts())
    print()

# %% [markdown]
# ### Classifying Transit Hubs and Low-Service Areas
#
# We classify each Louvain community using two metrics jointly:
#
# - **Transit hubs**: top 25% by Activity Per Stop AND above-median Average Temporal Activity
# - **Low-service areas**: bottom 25% by Activity Per Stop OR below-median stop count
#
# Using both metrics together avoids misclassifying communities that are spatially
# large but temporally inactive, or temporally active but infrastructure-poor.

# %%
# Thresholds based on quartiles of the activity-per-stop distribution
hub_threshold = service_summary["Activity Per Stop"].quantile(0.75)
low_service_threshold = service_summary["Activity Per Stop"].quantile(0.25)

transit_hubs = service_summary[
    (service_summary["Activity Per Stop"] >= hub_threshold) &
    (service_summary["Average Temporal Activity"] >= service_summary["Average Temporal Activity"].median())
]

low_service_areas = service_summary[
    (service_summary["Activity Per Stop"] <= low_service_threshold) |
    (service_summary["Number of Stops"] < service_summary["Number of Stops"].median())
]

print(f"Transit hubs identified: {len(transit_hubs)}")
print(f"Low-service areas identified: {len(low_service_areas)}")

fig, ax = plt.subplots(figsize=(12, 10))
queens_map.plot(ax=ax, color="lightgrey", edgecolor="black", alpha=0.5)

hubs_gdf = stops_gdf[stops_gdf["louvain_community"].isin(transit_hubs.index)]
low_service_gdf = stops_gdf[stops_gdf["louvain_community"].isin(low_service_areas.index)]

hubs_gdf = hubs_gdf[~hubs_gdf.geometry.is_empty & hubs_gdf.geometry.is_valid]
low_service_gdf = low_service_gdf[~low_service_gdf.geometry.is_empty & low_service_gdf.geometry.is_valid]

if not hubs_gdf.empty:
    hubs_gdf.plot(ax=ax, color="blue", markersize=50, label="Transit Hubs")
if not low_service_gdf.empty:
    low_service_gdf.plot(ax=ax, color="orange", markersize=50, label="Low-Service Areas")

plt.title("Transit Hubs and Low-Service Areas in Eastern Queens", fontsize=16)
plt.xlabel("Longitude", fontsize=12)
plt.ylabel("Latitude", fontsize=12)
plt.legend(loc="upper right", fontsize=10)
plt.tight_layout()
plt.savefig("../images/hubs_and_lsas_eastern_queens.png", dpi=300)
plt.show()

# %%
# Merge real-time data with stops to get vehicle activity at the neighborhood level
merged_data = stops_gdf.merge(
    real_time_data,
    on=["stop_id", "route_id"],
    how="left"
)

# Aggregate by neighborhood
service_summary_neighborhood = merged_data.groupby("ntaname").agg(
    louvain_community=("louvain_community", lambda x: list(set(x.dropna()))),
    stop_count=("stop_id", "count"),
    bus_activity_count=("vehicle_id", "count")
).reset_index()

service_summary_neighborhood["Activity-to-Stop Ratio"] = (
    service_summary_neighborhood["bus_activity_count"] /
    service_summary_neighborhood["stop_count"]
)

# Merge into queens_map for mapping
neighborhood_analysis = queens_map.merge(
    service_summary_neighborhood, on="ntaname", how="left"
)

# %%
fig, ax = plt.subplots(figsize=(12, 10))
neighborhood_analysis.plot(
    column="Activity-to-Stop Ratio",
    cmap="Blues",
    legend=True,
    ax=ax,
    edgecolor="black"
)
plt.title("Activity-to-Stop Ratio by Neighborhood")
plt.savefig("../images/activity_to_stop_ratio_heatmap.png", dpi=300)
plt.show()

print("Top 10 Underserved Neighborhoods by Activity-to-Stop Ratio:")
display(
    service_summary_neighborhood
    .sort_values("Activity-to-Stop Ratio")
    .head(10)
)

# %%
# Save key outputs for use in the Streamlit app and downstream analysis.
# Pickle files preserve GeoDataFrame geometry; CSVs are for plain data inspection.

# Route temporal cluster labels
with open(f"{data_directory}route_labels.pkl", "wb") as f:
    pickle.dump(route_labels, f)
print("Route clustering labels saved.")

# Neighborhood service summary
service_summary_neighborhood.to_csv(
    f"{data_directory}neighborhood_service_summary.csv", index=False
)
print("Neighborhood service summary saved.")

# HDBSCAN cluster assignments
stops_gdf[["stop_id", "hdbscan_cluster"]].to_csv(
    f"{data_directory}hdbscan_clusters.csv", index=False
)
print("HDBSCAN cluster assignments saved.")

# Louvain community assignments
stops_gdf[["stop_id", "louvain_community"]].to_csv(
    f"{data_directory}louvain_communities.csv", index=False
)

# Louvain community summary
louvain_summary = Counter(partition.values())
with open(f"{data_directory}louvain_summary.json", "w") as f:
    json.dump(dict(louvain_summary), f, indent=4)
print("Louvain community summary saved.")

# %% [markdown]
# ## Experimental Code
#
# The cells below document two approaches that were explored but abandoned:
#
# **DBSCAN** — Run before HDBSCAN. Finding a workable `epsilon` for geospatial data
# proved intractable: small changes to the parameter produced wildly different cluster
# structures with no stable optimum.
#
# **PageRank** — Promising in theory, but PageRank is designed for directed graphs.
# The transit network is better modeled as undirected, which caused PageRank scores
# to converge uniformly across stops.
#
# These cells are preserved to show the reasoning process, but their outputs are not
# used in the final analysis.

# %% [markdown]
# ### DBSCAN

# %%
eps = 0.00005
min_samples = 5
dbscan = DBSCAN(eps=eps, min_samples=min_samples, metric="haversine")
stops_gdf["dbscan_cluster"] = dbscan.fit_predict(
    np.radians(stops_gdf[["stop_lat", "stop_lon"]])
)

print("DBSCAN Cluster Counts:")
print(stops_gdf["dbscan_cluster"].value_counts())

# %%
visualize_clusters(
    stops_gdf,
    cluster_col="dbscan_cluster",
    title="DBSCAN Clusters Overlaid on Queens Neighborhoods",
    map_data=queens_map
)

# %% [markdown]
# ### PageRank
#
# PageRank was developed by Google to rank webpages by link importance. Applied to
# a transit graph, it should theoretically surface high-connectivity stops as hubs.
# In practice, the undirected nature of the bus network caused scores to be nearly
# uniform — PageRank's damping factor assumes direction, which doesn't apply here.

# %%
distance_threshold = 0.1  # kilometers

edges_pr = []
print("Constructing edges for PageRank...")
for stop1, stop2 in tqdm(combinations(stops_gdf["stop_id"], 2), desc="Computing edges"):
    coord1 = stops_gdf.loc[stops_gdf["stop_id"] == stop1, "coords"].values[0]
    coord2 = stops_gdf.loc[stops_gdf["stop_id"] == stop2, "coords"].values[0]
    if geodesic(coord1, coord2).kilometers <= distance_threshold:
        edges_pr.append((stop1, stop2))

print(f"Edges constructed: {len(edges_pr):,}")

# %%
G_pr = nx.DiGraph()

for _, row in stops_gdf.iterrows():
    G_pr.add_node(row["stop_id"], latitude=row["stop_lat"], longitude=row["stop_lon"])

G_pr.add_edges_from(edges_pr)

pagerank_scores = nx.pagerank(G_pr, alpha=0.85)
stops_gdf["pagerank"] = stops_gdf["stop_id"].map(pagerank_scores)

print("Top 10 Bus Stops by PageRank:")
print(stops_gdf.sort_values("pagerank", ascending=False)[["stop_id", "stop_name", "pagerank"]].head(10))

visualize_clusters(
    stops_gdf,
    cluster_col="pagerank",
    title="PageRank Scores Overlaid on Queens Neighborhoods",
    map_data=queens_map
)
